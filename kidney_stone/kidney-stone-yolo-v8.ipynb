# %% [markdown]
# # Import The Libraries

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.43  Python-3.10.14 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# Setup complete  (28 CPUs, 31.8 GB RAM, 210.9/931.5 GB disk)

# %%
# !nvidia-smi
# Out:
# Wed Apr 29 13:37:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.86                 Driver Version: 591.86         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 Ti   WDDM  |   00000000:01:00.0 Off |                  N/A |
# |  0%   35C    P8              3W /  160W |     579MiB /   8188MiB |     18%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            5644    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A            9320    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10676    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           13792      C   ...indows-x86_64-none\python.exe      N/A      |
# |    0   N/A  N/A           16356    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           20072    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           20984    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           21008    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           21016    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           22548    C+G   ....0.3912.86\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           22580    C+G   ...crosoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           22608    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           26124    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           27760      C   ...al\Programs\Ollama\ollama.exe      N/A      |
# |    0   N/A  N/A           29620      C   ...indows-x86_64-none\python.exe      N/A      |
# |    0   N/A  N/A           30272    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import glob
from PIL import Image
from IPython.display import display
from glob import glob
import cv2
import random
import os

import warnings
warnings.filterwarnings('ignore')

# %%
class Sys:
    EPOCHS = 30
    BATCH_SIZE = 32
    SEED = 6
    LEARNING_RATE = 0.001
    NUM_SAMPLES = 16
    OPTIMIZER = 'Adam'
    ds='dataset/data.yaml'
    samples='dataset/train/images/*'

# %%
image = cv2.imread('dataset/train/images/1-3-46-670589-33-1-63700700750188529100001-5659992199131706929_png_jpg.rf.32f57db5f742576e560a82af2a4666e7.jpg')
h, w, c = image.shape
plt.imshow(image)
plt.title(f"Image Shape: {w} x {h} and 3 channels")
plt.show()

# %%
# Define the paths to the images and labels directories
train_images = "dataset/train/images"
train_labels = "dataset/train/labels"

test_images = "dataset/test/images"
test_labels = "dataset/test/labels"

val_images = "dataset/valid/images"
val_labels = "dataset/valid/labels"

# Get a list of all the image files in the training images directory
image_files = os.listdir(train_images)

# Choose 16 random image files from the list
random_images = random.sample(image_files, 16)

# Set up the plot
fig, axs = plt.subplots(4, 4, figsize=(16, 16))

# Loop over the random images and plot the object detections
for i, image_file in enumerate(random_images):
    row = i // 4
    col = i % 4

    # Load the image
    image_path = os.path.join(train_images, image_file)
    image = cv2.imread(image_path)

    # Load the labels for this image
    label_file = os.path.splitext(image_file)[0] + ".txt"
    label_path = os.path.join(train_labels, label_file)
    with open(label_path, "r") as f:
        labels = f.read().strip().split("\n")

    # Loop over the labels and plot the object detections
    # Loop over the labels and plot the object detections
    for label in labels:
        if len(label.split()) != 5:
            continue
        class_id, x_center, y_center, width, height = map(float, label.split())
        x_min = int((x_center - width/2) * image.shape[1])
        y_min = int((y_center - height/2) * image.shape[0])
        x_max = int((x_center + width/2) * image.shape[1])
        y_max = int((y_center + height/2) * image.shape[0])
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 3)


    # Show the image with the object detections
    axs[row, col].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    axs[row, col].axis('off')

plt.show()

# %%
images_for_vis = glob(Sys.samples)
random_image = random.sample(images_for_vis, Sys.NUM_SAMPLES)

plt.figure(figsize=(12,10))
for i in range(Sys.NUM_SAMPLES):
    plt.subplot(4,4,i+1)
    plt.imshow(cv2.imread(random_image[i]))
    plt.axis('on')

# %% [markdown]
# # Build & Train The Model

# %%
import ultralytics
from ultralytics import YOLO

yolo_v8 = YOLO('yolov8x.pt')

# %%
result_predict = yolo_v8.predict(source = image, imgsz=(416))
# Out:
# 0: 352x416 (no detections), 37.5ms
# Speed: 0.7ms preprocess, 37.5ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 416)

# %%
# show results
plot = result_predict[0].plot()
plot = cv2.cvtColor(plot, cv2.COLOR_BGR2RGB)
display(Image.fromarray(plot))
# Out:
# <PIL.Image.Image image mode=RGB size=391x320>

# %%
v8_model = yolo_v8.train(data=Sys.ds,seed=Sys.SEED,epochs=Sys.EPOCHS, imgsz=480, patience=10, 
                         lr0=Sys.LEARNING_RATE, optimizer=Sys.OPTIMIZER, dropout=0.2,
                         verbose=True,project='ft_models',name='kidney_stone_yolo_v8')
# Out:
# Ultralytics 8.4.43  Python-3.10.14 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.2, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=480, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8x.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=kidney_stone_yolo_v8, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=ft_models, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\david\tao-healthcare-showcase\kidney_stone\runs\detect\ft_models\kidney_stone_yolo_v8, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=6, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8718931  ultralytics.nn.modules.head.Detect           [1, 16, None, [320, 640, 640]]
# Model summary: 210 layers, 68,153,571 parameters, 68,153,555 gradients, 258.1 GFLOPs
#
# Transferred 104/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 332.8126.8 MB/s, size: 15.3 KB)
# train: Scanning D:\david\tao-healthcare-showcase\kidney_stone\dataset\train\labels.cache... 1054 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1054/1054  0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 162.450.5 MB/s, size: 18.2 KB)
# val: Scanning D:\david\tao-healthcare-showcase\kidney_stone\dataset\valid\labels.cache... 123 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 123/123  0.0s
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Plotting labels to D:\david\tao-healthcare-showcase\kidney_stone\runs\detect\ft_models\kidney_stone_yolo_v8\labels.jpg...
# Image sizes 480 train, 480 val
# Using 8 dataloader workers
# Logging results to D:\david\tao-healthcare-showcase\kidney_stone\runs\detect\ft_models\kidney_stone_yolo_v8
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      7.49G      2.377      1.943      1.303         40        480: 100% ━━━━━━━━━━━━ 66/66 2.0s/it 2:101.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.1it/s 1.3s0.5s
#                    all        123        325       0.35        0.4      0.268     0.0789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      7.67G      2.128      1.056      1.119         56        480: 100% ━━━━━━━━━━━━ 66/66 1.9s/it 2:082.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s0.5s
#                    all        123        325      0.756      0.631       0.63      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      7.98G      2.114      1.055      1.124         50        480: 100% ━━━━━━━━━━━━ 66/66 2.9s/it 3:083.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5s/it 6.0s0.8sss
#                    all        123        325       0.76      0.628      0.637       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30       7.7G      2.064     0.9924      1.094         36        480: 100% ━━━━━━━━━━━━ 66/66 2.7s/it 2:552.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.5it/s 1.6s0.6s
#                    all        123        325      0.747      0.671      0.633      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30       8.2G      2.115     0.9765       1.07         49        480: 100% ━━━━━━━━━━━━ 66/66 1.8s/it 1:602.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s0.6s
#                    all        123        325      0.677       0.64      0.623      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      7.65G      2.046      0.971      1.097         28        480: 100% ━━━━━━━━━━━━ 66/66 1.3s/it 1:271.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.0it/s 2.0s0.7s
#                    all        123        325      0.815      0.677      0.676      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      7.65G       2.01     0.9374      1.094         44        480: 100% ━━━━━━━━━━━━ 66/66 1.5s/it 1:401.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.4s/it 5.4s2.5ss
#                    all        123        325      0.764      0.609      0.672      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      7.68G      1.963     0.9158      1.067         55        480: 100% ━━━━━━━━━━━━ 66/66 1.1s/it 1:151.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.4it/s 2.8s0.6s
#                    all        123        325      0.764      0.692        0.7      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      8.18G      1.995     0.9263      1.061         39        480: 100% ━━━━━━━━━━━━ 66/66 3.6s/it 4:013.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2s/it 4.7s2.2ss
#                    all        123        325      0.789      0.644      0.635      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      7.68G      1.917     0.8769      1.056         56        480: 100% ━━━━━━━━━━━━ 66/66 2.3s/it 2:321.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s1.1s
#                    all        123        325      0.774      0.708      0.683      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      8.19G      1.975     0.9027      1.058         56        480: 100% ━━━━━━━━━━━━ 66/66 2.9s/it 3:112.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3s/it 5.1s2.1ss
#                    all        123        325      0.796      0.702      0.718      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      8.18G      1.929     0.8696      1.046         63        480: 100% ━━━━━━━━━━━━ 66/66 3.7s/it 4:063.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.5s1.5ss
#                    all        123        325      0.808      0.695      0.729      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30       8.2G      1.964     0.8749      1.047         35        480: 100% ━━━━━━━━━━━━ 66/66 2.2s/it 2:232.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5s/it 5.9s0.9ss
#                    all        123        325      0.809      0.677      0.692      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      8.19G      1.912     0.8462      1.026         48        480: 100% ━━━━━━━━━━━━ 66/66 3.7s/it 4:033.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.1it/s 1.3s0.5s
#                    all        123        325       0.75      0.646      0.627      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      8.18G      1.891     0.8373      1.018         59        480: 100% ━━━━━━━━━━━━ 66/66 2.3s/it 2:322.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5s/it 6.2s0.8sss
#                    all        123        325      0.757      0.671      0.699       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      8.21G      1.907     0.8115      1.012         61        480: 100% ━━━━━━━━━━━━ 66/66 3.8s/it 4:114.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s0.5s
#                    all        123        325      0.792      0.703      0.704      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      8.18G      1.855     0.8096      1.045         49        480: 100% ━━━━━━━━━━━━ 66/66 2.6s/it 2:482.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5s/it 6.2s0.8s1s
#                    all        123        325      0.791        0.7      0.709      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      8.19G      1.829     0.8057      1.001         47        480: 100% ━━━━━━━━━━━━ 66/66 3.1s/it 3:243.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3s/it 5.4s2.6ss
#                    all        123        325      0.815      0.723      0.711      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      8.19G      1.816     0.7983       1.03         49        480: 100% ━━━━━━━━━━━━ 66/66 2.2s/it 2:252.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6s/it 6.4s1.7ss
#                    all        123        325      0.832      0.714      0.767      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      8.19G      1.863     0.7909      0.999         46        480: 100% ━━━━━━━━━━━━ 66/66 3.2s/it 3:303.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.4s
#                    all        123        325      0.785       0.73      0.722      0.278
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      8.19G      1.777     0.7888      1.025         38        480: 100% ━━━━━━━━━━━━ 66/66 2.5s/it 2:472.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6s/it 6.4s0.8s0s
#                    all        123        325      0.789      0.739      0.725      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      8.19G      1.766     0.7757      1.031         33        480: 100% ━━━━━━━━━━━━ 66/66 4.1s/it 4:293.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s0.5s
#                    all        123        325      0.784      0.742      0.764      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      8.19G      1.736     0.7536       1.02         29        480: 100% ━━━━━━━━━━━━ 66/66 3.8s/it 4:113.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6s/it 6.4s0.8s8s
#                    all        123        325      0.809      0.729      0.748      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      8.19G      1.738     0.7438      1.015         32        480: 100% ━━━━━━━━━━━━ 66/66 2.7s/it 2:582.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.4s/it 5.6s1.9ss
#                    all        123        325      0.819      0.736      0.751      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      7.67G      1.728     0.7405      1.016         19        480: 100% ━━━━━━━━━━━━ 66/66 1.1s/it 1:150.8sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2it/s 1.8s0.7s
#                    all        123        325      0.775      0.668      0.645       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      7.66G      1.697     0.7234      0.998         19        480: 100% ━━━━━━━━━━━━ 66/66 1.7s/it 1:491.4sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.4s/it 5.7s1.1ss
#                    all        123        325      0.755      0.711      0.694      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      8.19G      1.659     0.7019     0.9876         26        480: 100% ━━━━━━━━━━━━ 66/66 2.7s/it 2:562.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.0s1.2s
#                    all        123        325      0.804       0.72      0.729      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      7.66G      1.634     0.6874     0.9802         27        480: 100% ━━━━━━━━━━━━ 66/66 1.4s/it 1:341.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.4s/it 5.4s2.3ss
#                    all        123        325      0.796       0.72      0.729      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      7.64G      1.612     0.6831     0.9745         31        480: 100% ━━━━━━━━━━━━ 66/66 1.2s/it 1:190.9sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.7it/s 2.3s1.0s
#                    all        123        325      0.849      0.717      0.764      0.296
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 19, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 29 epochs completed in 1.369 hours.
# Optimizer stripped from D:\david\tao-healthcare-showcase\kidney_stone\runs\detect\ft_models\kidney_stone_yolo_v8\weights\last.pt, 136.7MB
# Optimizer stripped from D:\david\tao-healthcare-showcase\kidney_stone\runs\detect\ft_models\kidney_stone_yolo_v8\weights\best.pt, 136.7MB
#
# Validating D:\david\tao-healthcare-showcase\kidney_stone\runs\detect\ft_models\kidney_stone_yolo_v8\weights\best.pt...
# Ultralytics 8.4.43  Python-3.10.14 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# Model summary (fused): 113 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.8it/s 1.4s0.5s
#                    all        123        325      0.794      0.714      0.759      0.313
# Speed: 0.2ms preprocess, 8.1ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to D:\david\tao-healthcare-showcase\kidney_stone\runs\detect\ft_models\kidney_stone_yolo_v8

# %% [markdown]
# # Testing  the model

# %%
def stone_detection(img_path, model):
    img = cv2.imread(img_path)
    detect_result = model(img)
    detect_img = detect_result[0].plot()
    detect_img = cv2.cvtColor(detect_img, cv2.COLOR_BGR2RGB)
    return detect_img

# %%
df = 'dataset/test/images'
df_testing = os.listdir(df)

selected_images = random.sample(df_testing, 16)

# %%
model_trained = YOLO('runs/detect/ft_models/kidney_stone_yolo_v8/weights/best.pt')

# %%
# Create a figure with subplots for each image
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(15, 15))

for i, img_file in enumerate(selected_images):
    
    # Compute the row and column index of the current subplot
    row_idx = i // 4
    col_idx = i % 4
    
    # Load the current image and run object detection
    img_path = os.path.join(df, img_file)
    detect_img = stone_detection(img_path, model_trained)
    
    # Plot the current image on the appropriate subplot
    axes[row_idx, col_idx].imshow(detect_img)
    axes[row_idx, col_idx].axis('off')

# Adjust the spacing between the subplots
plt.subplots_adjust(wspace=0.05, hspace=0.05)
# Out:
# 0: 416x480 2 Stones, 57.1ms
# Speed: 0.9ms preprocess, 57.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 2 Stones, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 1 Stone, 31.1ms
# Speed: 0.9ms preprocess, 31.1ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 1 Stone, 31.1ms
# Speed: 1.0ms preprocess, 31.1ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 1 Stone, 31.0ms
# Speed: 0.8ms preprocess, 31.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 2 Stones, 31.1ms
# Speed: 1.1ms preprocess, 31.1ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 2 Stones, 28.6ms
# Speed: 0.9ms preprocess, 28.6ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 4 Stones, 14.2ms
# Speed: 0.8ms preprocess, 14.2ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 2 Stones, 14.3ms
# Speed: 0.7ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 1 Stone, 14.0ms
# Speed: 0.8ms preprocess, 14.0ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 2 Stones, 14.0ms
# Speed: 0.7ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 1 Stone, 14.3ms
# Speed: 0.7ms preprocess, 14.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 1 Stone, 14.3ms
# Speed: 0.8ms preprocess, 14.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 1 Stone, 14.3ms
# Speed: 0.7ms preprocess, 14.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 1 Stone, 14.3ms
# Speed: 0.8ms preprocess, 14.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 480)
#
# 0: 416x480 2 Stones, 14.3ms
# Speed: 0.8ms preprocess, 14.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 480)

# %%
results = pd.read_csv('runs/detect/ft_models/kidney_stone_yolo_v8/results.csv')
results
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   131.707         2.37697         1.94343         1.30343
# 1       2   262.980         2.12841         1.05551         1.11898
# 2       3   459.614         2.11362         1.05503         1.12422
# 3       4   638.781         2.06448         0.99240         1.09400
# 4       5   763.610         2.11501         0.97646         1.07027
# 5       6   854.983         2.04566         0.97102         1.09733
# 6       7   962.064         2.00960         0.93739         1.09395
# 7       8  1041.660         1.96300         0.91580         1.06705
# 8       9  1289.320         1.99456         0.92634         1.06138
# 9      10  1445.670         1.91736         0.87693         1.05629
# 10     11  1643.290         1.97481         0.90270         1.05773
# 11     12  1896.120         1.92860         0.86962         1.04577
# 12     13  2047.330         1.96377         0.87487         1.04654
# 13     14  2293.510         1.91247         0.84619         1.02640
# 14     15  2453.950         1.89089         0.83725         1.01830
# 15     16  2708.130         1.90711         0.81154         1.01235
# 16     17  2884.610         1.85488         0.80958         1.04519
# 17     18  3096.450         1.82887         0.80570         1.00066
# 18     19  3249.230         1.81642         0.79828         1.02958
# 19     20  3462.560         1.86291         0.79092         0.99896
# 20     21  3648.620         1.77659         0.78881         1.02521
# 21     22  3920.420         1.76579         0.77565         1.03081
# 22     23  4179.360         1.73600         0.75362         1.02022
# 23     24  4364.860         1.73821         0.74385         1.01539
# 24     25  4443.500         1.72794         0.74052         1.01564
# 25     26  4560.080         1.69738         0.72344         0.99805
# 26     27  4740.860         1.65908         0.70187         0.98762
# 27     28  4841.990         1.63445         0.68741         0.98020
# 28     29  4925.150         1.61205         0.68306         0.97452
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.35040            0.40000           0.26831
# 1                0.75645            0.63077           0.63033
# 2                0.76043            0.62769           0.63666
# 3                0.74652            0.67056           0.63302
# 4                0.67725            0.64000           0.62285
# 5                0.81494            0.67692           0.67602
# 6                0.76427            0.60923           0.67231
# 7                0.76391            0.69231           0.70002
# 8                0.78894            0.64408           0.63480
# 9                0.77447            0.70769           0.68341
# 10               0.79638            0.70154           0.71825
# 11               0.80771            0.69538           0.72899
# 12               0.80915            0.67692           0.69205
# 13               0.74970            0.64615           0.62694
# 14               0.75697            0.67086           0.69933
# 15               0.79209            0.70336           0.70438
# 16               0.79121            0.69960           0.70947
# 17               0.81488            0.72308           0.71117
# 18               0.83161            0.71418           0.76693
# 19               0.78505            0.73045           0.72166
# 20               0.78949            0.73855           0.72516
# 21               0.78417            0.74154           0.76411
# 22               0.80884            0.72923           0.74803
# 23               0.81861            0.73598           0.75115
# 24               0.77451            0.66769           0.64547
# 25               0.75505            0.71077           0.69448
# 26               0.80434            0.72000           0.72853
# 27               0.79582            0.71955           0.72884
# 28               0.84891            0.71692           0.76439
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0               0.07895       2.35388       3.37120       1.22837  0.000328
# 1               0.24346       2.06289       1.01713       1.08906  0.000640
# 2               0.23953       2.06782       1.01655       1.06195  0.000929
# 3               0.25272       2.02957       1.02895       1.05299  0.000901
# 4               0.22253       2.18414       0.99565       1.09768  0.000868
# 5               0.25089       1.99505       0.91712       1.04646  0.000835
# 6               0.24075       2.10667       0.98178       1.07059  0.000802
# 7               0.26908       2.01846       0.92972       1.04857  0.000769
# 8               0.23404       2.19297       0.93985       1.10813  0.000736
# 9               0.24903       2.14602       0.93488       1.08619  0.000703
# 10              0.26105       2.11239       0.92955       1.06993  0.000670
# 11              0.28891       2.04795       0.87320       1.05131  0.000637
# 12              0.27167       2.05201       0.91006       1.06665  0.000604
# 13              0.22133       2.29925       0.96646       1.12699  0.000571
# 14              0.25015       2.16847       0.96340       1.08222  0.000538
# 15              0.27064       2.10119       0.89476       1.06147  0.000505
# 16              0.27340       2.10943       0.88986       1.06965  0.000472
# 17              0.27390       2.10440       0.85562       1.06327  0.000439
# 18              0.31554       2.00008       0.82782       1.04104  0.000406
# 19              0.27816       2.11916       0.85296       1.09379  0.000373
# 20              0.27333       2.09908       0.88785       1.07016  0.000340
# 21              0.29419       2.05511       0.85569       1.02864  0.000307
# 22              0.28876       2.10731       0.84431       1.06103  0.000274
# 23              0.29148       2.06596       0.82123       1.05947  0.000241
# 24              0.23047       2.27413       0.93132       1.11107  0.000208
# 25              0.25826       2.17414       0.90438       1.08763  0.000175
# 26              0.27295       2.16863       0.87044       1.08710  0.000142
# 27              0.28323       2.08410       0.81799       1.06412  0.000109
# 28              0.29635       2.07043       0.80062       1.06517  0.000076
#
#       lr/pg1    lr/pg2
# 0   0.000328  0.067500
# 1   0.000640  0.034478
# 2   0.000929  0.001434
# 3   0.000901  0.000901
# 4   0.000868  0.000868
# 5   0.000835  0.000835
# 6   0.000802  0.000802
# 7   0.000769  0.000769
# 8   0.000736  0.000736
# 9   0.000703  0.000703
# 10  0.000670  0.000670
# 11  0.000637  0.000637
# 12  0.000604  0.000604
# 13  0.000571  0.000571
# 14  0.000538  0.000538
# 15  0.000505  0.000505
# 16  0.000472  0.000472
# 17  0.000439  0.000439
# 18  0.000406  0.000406
# 19  0.000373  0.000373
# 20  0.000340  0.000340
# 21  0.000307  0.000307
# 22  0.000274  0.000274
# 23  0.000241  0.000241
# 24  0.000208  0.000208
# 25  0.000175  0.000175
# 26  0.000142  0.000142
# 27  0.000109  0.000109
# 28  0.000076  0.000076

# %%
# Remove leading and trailing spaces from column names
results.columns = results.columns.str.strip()

epoch_column = results['epoch']
box_train_losses = results['train/box_loss']
box_val_losses = results['val/box_loss']
cls_train_losses = results['train/cls_loss']
cls_val_losses = results['val/cls_loss']

plt.figure(figsize=(12,5))
plt.style.use('ggplot')  # You can choose a style you prefer
plt.subplot(1,2,1)
plt.plot(epoch_column, box_train_losses, label='train_losses')
plt.plot(epoch_column, box_val_losses, label='val_losses')
plt.grid(True, linestyle='--', linewidth=0.5, color='gray')# Add a grid
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Box Losses')
plt.legend()

plt.subplot(1,2,2)
plt.plot(epoch_column, cls_train_losses, label='train_losses')
plt.plot(epoch_column, cls_val_losses, label='val_losses')
plt.grid(True, linestyle='--', linewidth=0.5, color='gray')# Add a grid
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Class Losses')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.imshow(cv2.imread('runs/detect/ft_models/kidney_stone_yolo_v8/results.png'))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(2399.5), np.float64(1199.5), np.float64(-0.5))

# %%
results.columns
# Out:
# Index(['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss',
#        'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'lr/pg0', 'lr/pg1', 'lr/pg2'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
plt.imshow(cv2.imread('runs/detect/ft_models/kidney_stone_yolo_v8/BoxPR_curve.png'))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(2249.5), np.float64(1499.5), np.float64(-0.5))

# %%
single_image='dataset/valid/images/1-3-46-670589-33-1-63737661477473189500001-5463064330587912766_png_jpg.rf.72d5fd49b7ea305b3167bb1d7ac8dbc7.jpg'

# %%
y = model_trained.predict(single_image)
print(type(y))
# Out:
# image 1/1 d:\david\tao-healthcare-showcase\kidney_stone\dataset\valid\images\1-3-46-670589-33-1-63737661477473189500001-5463064330587912766_png_jpg.rf.72d5fd49b7ea305b3167bb1d7ac8dbc7.jpg: 416x480 1 Stone, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 480)
# <class 'list'>

# %%
def show_single_image(img_file, df, model_trained, stone_detection):
    # Load the current image and run object detection
    # img_path = os.path.join(df, img_file)
    detect_img = stone_detection(img_file, model_trained)
    
    # Create a figure and axis for a single image
    fig, ax = plt.subplots(figsize=(5,5))
    
    # Plot the current image
    ax.imshow(detect_img)
    ax.axis('off')  
    
    plt.show()

# %%
show_single_image(single_image,df,model_trained,stone_detection)
# Out:
# 0: 416x480 1 Stone, 13.0ms
# Speed: 0.8ms preprocess, 13.0ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 480)

# %%
from ultralytics import YOLO
import pandas as pd

# Load your trained YOLO model
model = YOLO('runs/detect/ft_models/kidney_stone_yolo_v8/weights/best.pt')

# Validate on the test set
metrics = model.val(data="dataset/data.yaml", split="test", imgsz=480, batch=32)

# Collect metrics properly
report = {
    "mAP@0.5": metrics.box.map50,
    "mAP@0.5:0.95": metrics.box.map,
    "Precision (mean)": metrics.box.mp,
    "Recall (mean)": metrics.box.mr,
    "F1 (derived)": 2 * (metrics.box.mp * metrics.box.mr) /
                    (metrics.box.mp + metrics.box.mr + 1e-6),
    "Speed (ms/img)": metrics.speed["inference"] + metrics.speed["postprocess"]
}

# Print nicely
df_report = pd.DataFrame(report, index=["YOLOv8 Evaluation"])
print(df_report.T)
# Out:
# Ultralytics 8.4.43  Python-3.10.14 torch-2.9.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# Model summary (fused): 113 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 106.828.7 MB/s, size: 17.4 KB)
# val: Scanning D:\david\tao-healthcare-showcase\kidney_stone\dataset\test\labels.cache... 123 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 123/123  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.7it/s 2.3s0.9s
#                    all        123        224      0.818      0.692      0.711      0.314
# Speed: 1.4ms preprocess, 14.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to D:\david\tao-healthcare-showcase\kidney_stone\runs\detect\val
#                   YOLOv8 Evaluation
# mAP@0.5                    0.711075
# mAP@0.5:0.95               0.313880
# Precision (mean)           0.818438
# Recall (mean)              0.691964
# F1 (derived)               0.749905
# Speed (ms/img)            15.084822

# %%
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
